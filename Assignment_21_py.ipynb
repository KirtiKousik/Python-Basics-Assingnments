# %% [markdown]
# #### 1. Add the current date to the text file today.txt as a string.

# %%
import datetime
# Code to Add current date to the today.txt file
file = open('today.txt','w')
file.write(datetime.datetime.now().strftime("%d-%m-%Y"))
file.close()
# Code to Read current date from today.txt file
file = open('today.txt','r')
print(file.read())
file.close()
# Out:
# 13-12-2022

# %% [markdown]
# #### 2. Read the text file today.txt into the string today_string

# %%
file = open('today.txt','r')
today_string = file.read()
print(today_string)
# Out:
# 13-12-2022

# %% [markdown]
# #### 3. Parse the date from today_string.

# %%
from datetime import datetime
parsed_data = datetime.strptime(today_string, '%d-%m-%Y')
print(parsed_data)
# Out:
# 2022-12-13 00:00:00

# %% [markdown]
# #### 4. List the files in your current directory

# %%
import os
for folders, subfolders, files in os.walk(os.getcwd()):
    for file in files:
        print(file)
# Out:
# today.txt
# .last_opt_in_prompt.yaml
# gce
# active_config
# .last_update_check.json
# .last_survey_prompt.yaml
# config_sentinel
# 14.36.31.097271.log
# 14.37.04.370546.log
# 14.36.56.774366.log
# 14.37.32.030066.log
# 14.37.31.268045.log
# 14.36.06.559999.log
# config_default
# README.md
# anscombe.json
# mnist_train_small.csv
# california_housing_train.csv
# mnist_test.csv
# california_housing_test.csv

# %% [markdown]
# #### 5. Create a list of all of the files in your parent directory (minimum five files should be available).

# %%
import os 
os.listdir()
# Out:
# ['.config', 'today.txt', 'sample_data']

# %% [markdown]
# #### 6. Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

# %%
import multiprocessing
import time 
import random
import datetime

def procOne():
    print(f'Proc_one_Starttime -> {datetime.datetime.now()}\n')
    time.sleep(random.randint(1,5))
    print(f'Proc_one_Endtime -> {datetime.datetime.now()}\n')
    
def procTwo():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}\n')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}\n')

def procThree():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}\n')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}\n')
    
if __name__ == "__main__":    
    p1 = multiprocessing.Process(target=procOne)
    p2 = multiprocessing.Process(target=procTwo)
    p3 = multiprocessing.Process(target=procThree)

    p1.start()
    p2.start()
    p3.start()

    p1.join()
    p2.join()
    p3.join()
# Out:
# Proc_one_Starttime -> 2022-12-13 09:19:04.813889
#
# Proc_two_Starttime -> 2022-12-13 09:19:04.825085
#
# Proc_two_Starttime -> 2022-12-13 09:19:04.840589
#
# Proc_two_Endtime -> 2022-12-13 09:19:06.832631
# Proc_one_Endtime -> 2022-12-13 09:19:06.833788
#
#
# Proc_two_Endtime -> 2022-12-13 09:19:09.853672

# %% [markdown]
# #### 7. Create a date object of your day of birth.

# %%
from datetime import datetime
my_dob = datetime.strptime('24/12/1998','%d/%m/%Y')
print(my_dob, type(my_dob))
# Out:
# 1998-12-24 00:00:00 <class 'datetime.datetime'>

# %% [markdown]
# #### 8. What day of the week was your day of birth?

# %%
from datetime import datetime
my_dob = datetime(1998,12,24)
my_dob.strftime("%A")
# Out:
# 'Thursday'

# %% [markdown]
# #### 9. When will you be (or when were you) 10,000 days old?

# %%
from datetime import datetime, timedelta
my_dob = datetime.strptime("24/12/1998",'%d/%m/%Y')
future_date = my_dob+timedelta(10000)
future_date
# Out:
# datetime.datetime(2026, 5, 11, 0, 0)
