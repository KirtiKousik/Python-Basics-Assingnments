# %% [markdown]
# #### 1. Why are functions advantageous to have in your programs?

# %% [markdown]
# - Ans: Functions reduce the need for duplicate code. This makes programs shorter, easier to read, and easier to update.

# %% [markdown]
# #### 2. When does the code in a function run: when it&#39;s specified or when it&#39;s called?

# %% [markdown]
# - Ans: The code in a function executes when the function is called, not when the function is defined.

# %% [markdown]
# #### 3. What statement creates a function?

# %% [markdown]
# - Ans: We use def keyword, followed by the function name and a colon to create a function in python.
#     - i.e. def test( ):
#     - test( ) is the function

# %% [markdown]
# #### 4. What is the difference between a function and a function call?

# %% [markdown]
# - Ans:
#     - A function is a block of code that does a particular operation and returns a result. It usually accepts inputs as parameters and returns a result. The parameters are not mandatory.
#     - A function call is the code used to pass control to a function.

# %% [markdown]
# #### 5. How many global scopes are there in a Python program? How many local scopes?

# %% [markdown]
# - Ans:
#     - There's only one global Python scope per program execution.
#     - The local scope or function scope is a Python scope created at function calls. Every time we call a function, we’re also creating a new local scope.

# %% [markdown]
# #### 6. What happens to variables in a local scope when the function call returns?

# %% [markdown]
# - Ans: When the execution of the function terminates (returns), the local variables are destroyed.

# %% [markdown]
# #### 7. What is the concept of a return value? Is it possible to have a return value in an expression?

# %% [markdown]
# - Ans:
#     - A return is a value that a function returns to the calling script or function when it completes its task. A return value can be any one of the four variable types: handle, integer, object, or string. The type of value your function returns depends largely on the task it performs.
#     - Is it possible to have a return value in an expression Python?
# A Python function will always have a return value. There is no notion of procedure or routine in Python. So, if you don't explicitly use a return value in a return statement, or if you totally omit the return statement, then Python will implicitly return a default value for you.

# %% [markdown]
# #### 8. If a function does not have a return statement, what is the return value of a call to that function?

# %% [markdown]
# - Ans: There is no notion of procedure or routine in Python. So, if you don't explicitly use a return value in a return statement, or if you totally omit the return statement, then Python will implicitly return a default value for you. That default return value will always be None.

# %% [markdown]
# #### 9. How do you make a function variable refer to the global variable?

# %% [markdown]
# - Ans: Normally, when you create a variable inside a function, that variable is local, and can only be used inside that function. To create a global variable inside a function, you can use the global keyword.

# %%
# Example

def myfunc():
  global x
  x = "Kirti"

myfunc()

print("My name is " + x)
# Out:
# My name is Kirti

# %% [markdown]
# #### 10. What is the data type of None?

# %% [markdown]
# - Ans: The data type of None is NoneType.

# %%
type(None)
# Out:
# NoneType

# %% [markdown]
# #### 11. What does the sentence import areallyourpetsnamederic do?

# %% [markdown]
# - Ans: That import statement imports a module named areallyourpetsnamederic(not a real python module).

# %% [markdown]
# #### 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

# %% [markdown]
# - Ans: spam.bacon( )

# %% [markdown]
# #### 13. What can you do to save a program from crashing if it encounters an error?

# %% [markdown]
# - Ans: Each and every exception has to be handled by the programmer to avoid the program from crashing abruptly. This is done by writing additional code in a program to give proper messages or instructions to the user on encountering an exception. This process is known as exception handling.

# %% [markdown]
# #### 14. What is the purpose of the try clause? What is the purpose of the except clause?

# %% [markdown]
# - Ans:
#     - The try block lets us test a block of code for errors.
#     - The except block lets us handle the error.
