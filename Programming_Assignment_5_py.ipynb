# %% [markdown]
# #### 1. Write a Python Program to Find LCM?

# %%
def compute_lcm(x, y):

   if x > y:
       greater = x
   else:
       greater = y

   while True:
       if greater % x == 0 and greater % y == 0:
           lcm = greater
           break
       greater += 1

   return lcm

num1 = int(input('num1 = '))
num2 = int(input('num2 = '))

print("The L.C.M. is", compute_lcm(num1, num2))
# Out:
# num1 = 10
# num2 = 3
# The L.C.M. is 30

# %% [markdown]
# #### 2. Write a Python Program to Find HCF?

# %%
def compute_hcf(x, y):
    if x > y:
        smaller = y
    else:
        smaller = x
    for i in range(1, smaller+1):
        if((x % i == 0) and (y % i == 0)):
            hcf = i 
    return hcf

num1 = int(input('num1 = '))
num2 = int(input('num2 = '))

print("The H.C.F. is", compute_hcf(num1, num2))
# Out:
# num1 = 50
# num2 = 25
# The H.C.F. is 25

# %% [markdown]
# #### 3. Write a Python Program to Convert Decimal to Binary, Octal and Hexadecimal?

# %%
dec = int(input('Enter the decimal number: '))
print('The binary number is',bin(dec))
print('The octal number is',oct(dec))
print('The hexadecimal number is',hex(dec))
# Out:
# Enter the decimal number: 344
# The binary number is 0b101011000
# The octal number is 0o530
# The hexadecimal number is 0x158

# %% [markdown]
# #### 4. Write a Python Program To Find ASCII value of a character?

# %%
c = input('Enter a single character: ')
print(f"The ASCII value of {c} is", ord(c))
# Out:
# Enter a single character: k
# The ASCII value of k is 107

# %% [markdown]
# #### 5. Write a Python Program to Make a Simple Calculator with 4 basic mathematical operations?

# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    return x / y


print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

while True:
    choice = input("Enter choice(1/2/3/4): ")

    if choice in ('1', '2', '3', '4'):
        num1 = float(input("Enter first number: "))
        num2 = float(input("Enter second number: "))

        if choice == '1':
            print(num1, "+", num2, "=", add(num1, num2))

        elif choice == '2':
            print(num1, "-", num2, "=", subtract(num1, num2))

        elif choice == '3':
            print(num1, "*", num2, "=", multiply(num1, num2))

        elif choice == '4':
            print(num1, "/", num2, "=", divide(num1, num2))

        next_calculation = input("You want to calculate anything else? (y/n): ")
        if next_calculation == "n":
          break
    
    else:
        print("Invalid Input")
# Out:
# Select operation.
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# Enter choice(1/2/3/4): 4
# Enter first number: 15
# Enter second number: 3
# 15.0 / 3.0 = 5.0
# You want to calculate anything else? (y/n): n
