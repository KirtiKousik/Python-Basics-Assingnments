# %% [markdown]
# #### 1. Write a Python program to print &quot;Hello Python&quot;?

# %%
print('Hello Python')
# Out:
# Hello Python

# %% [markdown]
# #### 2. Write a Python program to do arithmetical operations addition and division.?

# %%
a = 10
b = 5
sum = a+b
div = a/b
print('The addition value is',sum)
print('The division value is',div)
# Out:
# The addition value is 15
# The division value is 2.0

# %% [markdown]
# #### 3. Write a Python program to find the area of a triangle?

# %%
radius = int(input("enter the radius of the circle: "))
print("The area of the circle is:", 3.141*radius*radius)
# Out:
# enter the radius of the circle: 5
# The area of the circle is: 78.525

# %% [markdown]
# #### 4. Write a Python program to swap two variables?

# %%
a = 10
b = 5
print('before swap')
print(a)
print(b)

c = a
a = b
b = c

print('After swap')
print(a)
print(b)
# Out:
# before swap
# 10
# 5
# After swap
# 5
# 10

# %% [markdown]
# #### 5. Write a Python program to generate a random number?

# %%
import random
print(random.randint(0,9))  # it generate a random number in range 0 to 9
# Out:
# 6
